# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the dataset
data = pd.read_csv('sorting_results.csv')

# Filter the data to include only HybridMergeSort
hybrid_merge_sort_data = data[data['Algorithm'] == 'HybridMergeSort']

# Get unique thresholds from the data
unique_thresholds = hybrid_merge_sort_data['Threshold'].unique()

# Set the number of columns for subplots
n_cols = 3  # Number of graphs per row
n_rows = (len(unique_thresholds) + n_cols - 1) // n_cols  # Calculate rows needed

# Create subplots with increased height for better layout
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, n_rows * 4))  # Increase height proportionally
axes = axes.flatten()  # Flatten the axes array for easy indexing

# To store average gradients for each threshold
average_gradients = []

# Loop through each threshold, plot the comparisons for different array sizes
for idx, threshold in enumerate(unique_thresholds):
    # Filter data for the current threshold
    threshold_data = hybrid_merge_sort_data[hybrid_merge_sort_data['Threshold'] == threshold]
    
    # Sort data by Array Size to ensure proper calculation of gradients
    threshold_data = threshold_data.sort_values(by='Array Size')

    # Calculate the gradients (change in Comparisons / change in Array Size)
    array_sizes = threshold_data['Array Size'].values
    comparisons = threshold_data['Comparisons'].values
    gradients = np.diff(comparisons) / np.diff(array_sizes)  # Calculate gradient between consecutive points
    
    # Calculate the average gradient
    avg_gradient = np.mean(gradients)
    average_gradients.append((threshold, avg_gradient))

    # Plot for HybridMergeSort with the current threshold
    axes[idx].plot(array_sizes, comparisons, marker='o', color='orange')
    axes[idx].set_title(f'Threshold={threshold} (Avg Gradient={avg_gradient:.2f})')
    axes[idx].set_xlabel('Array Size')
    axes[idx].set_ylabel('Comparisons')
    axes[idx].grid(True)

    # Annotate the plot with gradient values
    for i in range(len(gradients)):
        midpoint_x = (array_sizes[i] + array_sizes[i+1]) / 2
        midpoint_y = (comparisons[i] + comparisons[i+1]) / 2
        axes[idx].annotate(f'{gradients[i]:.2f}', (midpoint_x, midpoint_y), textcoords="offset points", xytext=(0,5), ha='center')

# Hide any empty subplots (if the number of thresholds is less than n_rows * n_cols)
for i in range(len(unique_thresholds), len(axes)):
    fig.delaxes(axes[i])

# Adjust layout
plt.tight_layout()
plt.show()

# Output the average gradients for each threshold
for threshold, avg_gradient in average_gradients:
    print(f'Threshold={threshold}, Average Gradient={avg_gradient:.2f}')
# Out:
# Threshold=1, Average Gradient=16.91
# Threshold=5, Average Gradient=17.04
# Threshold=8, Average Gradient=17.16
# Threshold=10, Average Gradient=17.43
# Threshold=15, Average Gradient=17.63
# Threshold=16, Average Gradient=17.65
# Threshold=20, Average Gradient=18.82
# Threshold=25, Average Gradient=19.51
# Threshold=30, Average Gradient=19.42
# Threshold=32, Average Gradient=19.36
# Threshold=35, Average Gradient=19.37
# Threshold=40, Average Gradient=22.20
# Threshold=45, Average Gradient=22.21
# Threshold=50, Average Gradient=23.94
# Threshold=55, Average Gradient=23.92
# Threshold=60, Average Gradient=23.98
# Threshold=65, Average Gradient=23.54
# Threshold=70, Average Gradient=23.59
# Threshold=75, Average Gradient=26.31
# Threshold=80, Average Gradient=29.90
# Threshold=85, Average Gradient=29.92
# Threshold=90, Average Gradient=29.86
# Threshold=95, Average Gradient=29.87
# Threshold=100, Average Gradient=33.48
# Threshold=124, Average Gradient=32.89
# Threshold=200, Average Gradient=53.46
# Threshold=250, Average Gradient=52.38
# Threshold=300, Average Gradient=52.14
# Threshold=350, Average Gradient=79.28
# Threshold=400, Average Gradient=94.44
# Threshold=450, Average Gradient=94.67
# Threshold=500, Average Gradient=92.42
# Threshold=550, Average Gradient=92.41
# Threshold=650, Average Gradient=146.83
# Threshold=750, Average Gradient=147.08
# Threshold=850, Average Gradient=178.33
# Threshold=900, Average Gradient=177.91
# Threshold=950, Average Gradient=178.21

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('sorting_results.csv')

# Filter the data to include only the rows for a specific threshold
threshold_value = 5  # Example threshold value (you can change this)
filtered_data = data[data['Threshold'] == threshold_value]

# Separate data for each algorithm (MergeSort and HybridMergeSort)
merge_sort_data = filtered_data[filtered_data['Algorithm'] == 'MergeSort']
hybrid_merge_sort_data = filtered_data[filtered_data['Algorithm'] == 'HybridMergeSort']

# Plot Time (ms) vs Array Size for MergeSort
plt.figure(figsize=(8, 6))
plt.plot(merge_sort_data['Array Size'], merge_sort_data['Time (ms)'], marker='o', label='MergeSort', color='blue')
plt.plot(hybrid_merge_sort_data['Array Size'], hybrid_merge_sort_data['Time (ms)'], marker='o', label='HybridMergeSort', color='orange')
plt.title(f'Time Complexity vs Array Size (Threshold={threshold_value})')
plt.xlabel('Array Size')
plt.ylabel('Time (ms)')
plt.legend()
plt.grid(True)
plt.show()
