# %%
import pandas as pd
import numpy as np

# %%
def merge(slot, start, midpointer, end):
    print(f"slot Before merge: {slot}")
    print(f"start: {start}, mid: {midpointer}, end: {end}")

    n = start
    m = end
    mid = midpointer
    a = n
    b = mid + 1

    if m - n <= 0:
        return

    while a <= mid and b <= m:
        comparison = is_first_larger(slot[a], slot[b])

        if comparison == 0:  # slot[a] < slot[b] (no swap needed)
            a += 1
        elif comparison == 1:  # slot[a] > slot[b]
            tmp = slot[b]
            b += 1

            for i in range(mid + 1, a, -1):
                slot[i] = slot[i - 1]

            slot[a] = tmp
            a += 1
            mid += 1
        elif comparison == 2:  # slot[a] == slot[b]
            if a==mid and b ==m:
                break
            tmp = slot[b]
            b += 1
            a += 1
            mid += 1
            for i in range(mid,a,-1):
                slot[i] = slot[i-1]
            slot[a] = tmp

    print(f"slot After merge: {slot}")


def merge_sort(slot):
    if len(slot) > 1:
        print(f"slot: {slot}")
        left = slot[:len(slot) // 2]
        right = slot[len(slot) // 2:]

        print(f"left: {left}")
        print(f"right: {right}")
        print("=" * 100)

        merge_sort(left)
        merge_sort(right)

        slot[:] = left + right

        merge(slot, 0, len(left) - 1, len(slot) - 1)

    return slot


def is_first_larger(x, y):
    if x > y:
        return 1
    elif x < y:
        return 0
    else:
        return 2


# Example usage:
# Define the size of the array
size = 1000000  # Example size

# Define the range of random integers
low = 0
high = 10000000

# Generate the random integer array in chunks
chunk_size = 0  # Define chunk size

for _ in range(10):
    chunk_size += 10
    arr = np.random.randint(0, 100, chunk_size)
    print(arr)
    sorted_arr = merge_sort(arr)
    print(f"Sorted array: {sorted_arr}")
# Out:
# [88  0 76 86 78 88 95 69 10 56]
# slot: [88  0 76 86 78 88 95 69 10 56]
# left: [88  0 76 86 78]
# right: [88 95 69 10 56]
# ====================================================================================================
# slot: [88  0 76 86 78]
# left: [88  0]
# right: [76 86 78]
# ====================================================================================================
# slot: [88  0]
# left: [88]
# right: [0]
# ====================================================================================================
# slot Before merge: [88 88]
# start: 0, mid: 0, end: 1
# slot After merge: [88 88]
# slot: [76 86 78]
# left: [76]
# right: [86 78]
# ====================================================================================================
# slot: [86 78]
# left: [86]
# right: [78]
# ====================================================================================================
# slot Before merge: [164 164]
# start: 0, mid: 0, end: 1
# slot After merge: [164 164]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 87
#      85 arr = np.random.randint(0, 100, chunk_size)
#      86 print(arr)
# ---> 87 sorted_arr = merge_sort(arr)
#      88 print(f"Sorted array: {sorted_arr}")
#
# Cell In[4], line 53, in merge_sort(slot)
#      50 print(f"right: {right}")
#      51 print("=" * 100)
# ---> 53 merge_sort(left)
#      54 merge_sort(right)
#      56 slot[:] = left + right
#
# Cell In[4], line 54, in merge_sort(slot)
#      51 print("=" * 100)
#      53 merge_sort(left)
# ---> 54 merge_sort(right)
#      56 slot[:] = left + right
#      58 merge(slot, 0, len(left) - 1, len(slot) - 1)
#
# Cell In[4], line 56, in merge_sort(slot)
#      53     merge_sort(left)
#      54     merge_sort(right)
# ---> 56     slot[:] = left + right
#      58     merge(slot, 0, len(left) - 1, len(slot) - 1)
#      60 return slot
#
# ValueError: could not broadcast input array from shape (2,) into shape (3,)
