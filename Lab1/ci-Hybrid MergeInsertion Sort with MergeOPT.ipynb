# %%
import random
import pandas as pd

# %%
hybrid_df = pd.DataFrame(columns = ['n', 'number_of_key_comparisons'])

# %%
def generate_random_array(length, min_value=0, max_value=1000000):
    """
    Generate a random array of integers.
    
    Parameters:
    length (int): Length of the array.
    min_value (int): Minimum value for array elements.
    max_value (int): Maximum value for array elements.

    Returns:
    list: A list of random integers.
    """
    return [random.randint(min_value, max_value) for _ in range(length)]

def check_if_sorted(arr):
    not_sorted = False
    for i in range(len(arr) - 1):
        if arr[i] > arr[i + 1]:
            not_sorted = True
            break
    if not_sorted:
        print("NOT SORTED")
    else:
        print("SORTED")

# %%
def insertion_sort(a_list, start, end):
    global comparison_count
    for i in range(start + 1, end + 1):
        for j in range(i, start, -1):
            comparison_count += 1
            if a_list[j] < a_list[j - 1]:
                a_list[j], a_list[j - 1] = a_list[j - 1], a_list[j]
            else:
                break


def merge(slot, start, midpointer, end):
    global comparison_count
    n = start
    m = end
    mid = midpointer
    a = n
    b = mid + 1

    if m - n <= 0:
        return

    while a <= mid and b <= m:
        comparison_count += 1
        if slot[a] < slot[b]:  # No swap needed #ZW changed
            a += 1
        elif slot[a] > slot[b]:  # slot[a] > slot[b]
            tmp = slot[b]
            b += 1
            for i in range(mid + 1, a, -1):
                slot[i] = slot[i - 1]
            slot[a] = tmp
            a += 1
            mid += 1
        else:  # slot[a] == slot[b]
            if a == mid and b == m:
                break
            tmp = slot[b]
            b += 1
            a += 1
            for i in range(mid + 1, a, -1):
                slot[i] = slot[i - 1]
            slot[a] = tmp
            a += 1
            break


def mergeOPT(slot, start, midpointer, end):
    global comparison_count
    left = slot[start:midpointer+1]
    right = slot[midpointer+1:end+1]
    '''
    print(start)
    print(end)
    print(left)
    print(right)
    '''

    i = 0
    j = 0
    k = start

    while i < len(left) and j < len(right):
        comparison_count += 1
        if left[i] <= right[j]:
            slot[k] = left[i]
            k += 1
            i += 1
        else:
            slot[k] = right[j]
            k += 1
            j += 1

    while i < len(left):
        slot[k] = left[i]
        k += 1
        i += 1

    while j < len(right):
        slot[k] = right[j]
        k += 1
        j += 1

    '''
    print(slot)
    print()
    '''

def merge_insertion_sort(slot, start, end, threshold):
    if end - start <= threshold:
        insertion_sort(slot, start, end)
    else:
        mid = (start + end) // 2

        merge_insertion_sort(slot, start, mid, threshold)
        merge_insertion_sort(slot, mid + 1, end, threshold)

        mergeOPT(slot, start, mid, end)


def hybrid_merge_insertion_sort(arr, threshold=8):
    global comparison_count
    comparison_count = 0
    merge_insertion_sort(arr, 0, len(arr) - 1, threshold)
    return arr

# %%
# Original Merge Sort Implementation
def merge_sort(arr, start, end):
    if start < end:
        mid = (start + end) // 2
        merge_sort(arr, start, mid)
        merge_sort(arr, mid + 1, end)
        mergeOPT(arr, start, mid, end)


def standard_merge_sort(arr):
    global comparison_count
    comparison_count = 0
    merge_sort(arr, 0, len(arr) - 1)
    return arr

# %%
# Fixed S = 8, diffrent n, increase by 4000
n = 1000
j = 0

while n <= 10000000:
    print(n)
    ave_comparison_counts_hybrid = 0
    
    for i in range(3):
        arr = generate_random_array(n)

        # Reset and use hybrid_merge_insertion_sort
        global comparison_count
        comparison_count = 0
        sorted_arr_hybrid = hybrid_merge_insertion_sort(arr.copy())
        ave_comparison_counts_hybrid += comparison_count
    
    ave_comparison_counts_hybrid //= 3
    
    # Output the number of comparisons for each array and each method
    print("Hybrid Merge-Insertion Sort Comparisons:")
    print(f"Average: {ave_comparison_counts_hybrid}")
    hybrid_df.loc[j] = [n, ave_comparison_counts_hybrid]
    
    j += 1
    n += 9000

display(hybrid_df)
# Out:
# 1000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 9124
# 10000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 122501
# 19000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 254471
# 28000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 387033
# 37000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 535595
# 46000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 663335
# 55000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 813086
# 64000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 968110
# 73000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 1127854
# 82000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 1245572
# 91000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 1401309
# 100000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 1558083
# 109000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 1718111
# 118000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 1880669
# 127000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 2046179
# 136000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 2213746
# 145000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 2383320
# 154000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 2518033
# 163000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 2641032
# 172000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 2800879
# 181000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 2965603
# 190000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 3131069
# 199000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 3296453
# 208000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 3466659
# 217000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 3636011
# 226000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 3805159
# 235000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 3977895
# 244000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 4152055
# 253000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 4325890
# 262000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 4501030
# 271000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 4679505
# 280000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 4858640
# 289000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 5036838
# 298000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 5200634
# 307000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 5330820
# 316000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 5462177
# 325000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 5593280
# 334000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 5753541
# 343000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 5927481
# 352000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 6101541
# 361000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 6274156
# 370000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 6448534
# 379000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 6622522
# 388000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 6796674
# 397000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 6972433
# 406000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 7151109
# 415000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 7329615
# 424000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 7506610
# 433000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 7685914
# 442000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 7864234
# 451000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 8043787
# 460000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 8222624
# 469000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 8404626
# 478000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 8588350
# 487000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 8771437
# 496000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 8954999
# 505000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 9137142
# 514000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 9320493
# 523000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 9503990
# 532000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 9691472
# 541000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 9879319
# 550000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 10068755
# 559000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 10254608
# 568000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 10442296
# 577000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 10631397
# 586000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 10817892
# 595000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 10978593
# 604000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 11119102
# 613000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 11260520
# 622000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 11399592
# 631000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 11540218
# 640000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 11680587
# 649000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 11820827
# 658000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 11973646
# 667000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 12156563
# 676000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 12338512
# 685000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 12520748
# 694000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 12703540
# 703000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 12886256
# 712000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 13068308
# 721000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 13250895
# 730000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 13434073
# 739000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 13616859
# 748000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 13799515
# 757000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 13982961
# 766000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 14166050
# 775000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 14347782
# 784000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 14531094
# 793000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 14717979
# 802000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 14905037
# 811000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 15092014
# 820000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 15280023
# 829000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 15466046
# 838000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 15654256
# 847000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 15842744
# 856000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 16029851
# 865000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 16216790
# 874000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 16404321
# 883000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 16591467
# 892000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 16780420
# 901000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 16967198
# 910000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 17155848
# 919000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 17343920
# 928000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 17534836
# 937000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 17727288
# 946000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 17920953
# 955000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 18111891
# 964000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 18303251
# 973000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 18496335
# 982000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 18688078
# 991000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 18880466
# 1000000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 19073035
# 1009000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 19264364
# 1018000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 19457800
# 1027000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 19649993
# 1036000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 19842950
# 1045000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 20034106
# 1054000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 20228078
# 1063000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 20426167
# 1072000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 20623908
# 1081000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 20819153
# 1090000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 21016491
# 1099000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 21212984
# 1108000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 21410114
# 1117000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 21605082
# 1126000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 21803618
# 1135000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 22000966
# 1144000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 22199131
# 1153000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 22395157
# 1162000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 22592845
# 1171000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 22788848
# 1180000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 22984606
# 1189000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 23131734
# 1198000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 23281450
# 1207000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 23429519
# 1216000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 23582012
# 1225000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 23729785
# 1234000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 23879937
# 1243000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 24028839
# 1252000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 24177323
# 1261000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 24325955
# 1270000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 24476074
# 1279000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 24626079
# 1288000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 24774842
# 1297000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 24923290
# 1306000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 25072373
# 1315000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 25243085
# 1324000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 25433686
# 1333000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 25624844
# 1342000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 25816546
# 1351000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 26008381
# 1360000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 26198055
# 1369000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 26390677
# 1378000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 26581947
# 1387000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 26773757
# 1396000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 26965246
# 1405000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 27157208
# 1414000
# Hybrid Merge-Insertion Sort Comparisons:
# Average: 27349306
# 1423000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 15
#      13     global comparison_count
#      14     comparison_count = 0
# ---> 15     sorted_arr_hybrid = hybrid_merge_insertion_sort(arr.copy())
#      16     ave_comparison_counts_hybrid += comparison_count
#      18 ave_comparison_counts_hybrid //= 3
#
# Cell In[4], line 104, in hybrid_merge_insertion_sort(arr, threshold)
#     102 global comparison_count
#     103 comparison_count = 0
# --> 104 merge_insertion_sort(arr, 0, len(arr) - 1, threshold)
#     105 return arr
#
# Cell In[4], line 96, in merge_insertion_sort(slot, start, end, threshold)
#      93 mid = (start + end) // 2
#      95 merge_insertion_sort(slot, start, mid, threshold)
# ---> 96 merge_insertion_sort(slot, mid + 1, end, threshold)
#      98 mergeOPT(slot, start, mid, end)
#
# Cell In[4], line 95, in merge_insertion_sort(slot, start, end, threshold)
#      92 else:
#      93     mid = (start + end) // 2
# ---> 95     merge_insertion_sort(slot, start, mid, threshold)
#      96     merge_insertion_sort(slot, mid + 1, end, threshold)
#      98     mergeOPT(slot, start, mid, end)
#
# Cell In[4], line 95, in merge_insertion_sort(slot, start, end, threshold)
#      92 else:
#      93     mid = (start + end) // 2
# ---> 95     merge_insertion_sort(slot, start, mid, threshold)
#      96     merge_insertion_sort(slot, mid + 1, end, threshold)
#      98     mergeOPT(slot, start, mid, end)
#
# Cell In[4], line 98, in merge_insertion_sort(slot, start, end, threshold)
#      95 merge_insertion_sort(slot, start, mid, threshold)
#      96 merge_insertion_sort(slot, mid + 1, end, threshold)
# ---> 98 mergeOPT(slot, start, mid, end)
#
# Cell In[4], line 63, in mergeOPT(slot, start, midpointer, end)
#      60 j = 0
#      61 k = start
# ---> 63 while i < len(left) and j < len(right):
#      64     comparison_count += 1
#      65     if left[i] <= right[j]:
#
# KeyboardInterrupt:
